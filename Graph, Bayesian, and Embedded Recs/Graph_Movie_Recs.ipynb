# %%
import networkx as nx
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
movies = pd.read_csv('/content/drive/MyDrive/Portfolio/Github-Recommender-System-master/movielens.csv')

# %%
movies['user_id'] = movies['user_id'].apply(str)
movies['user_id'] = 'u' + movies['user_id'].astype(str)

# %%
movies['movie_id'] = movies['movie_id'].apply(str)
movies['movie_id'] = 'm' + movies['movie_id'].astype(str)

# %%
liked_movies = movies.loc[movies['rating'] > 3]
liked_movies.head()
# Out:
#    Unnamed: 0 user_id movie_id  rating  ...  sex  occupation  zip_code  age_group
# 2           2    u195     m110       4  ...    1          20       415          3
# 3           3    u195      m24       4  ...    1          20       415          3
# 4           4    u195     m381       4  ...    1          20       415          3
# 6           6    u195     m152       5  ...    1          20       415          3
# 7           7    u195     m285       5  ...    1          20       415          3
#
# [5 rows x 27 columns]

# %%
u195 = liked_movies.loc[liked_movies['user_id'] == 'u195']
u195list = list(u195['movie_id'])
u195list
# Out:
# ['m110',
#  'm24',
#  'm381',
#  'm152',
#  'm285',
#  'm844',
#  'm237',
#  'm380',
#  'm305',
#  'm7',
#  'm654',
#  'm691',
#  'm1021',
#  'm284',
#  'm392',
#  'm662',
#  'm427',
#  'm410',
#  'm1006',
#  'm66',
#  'm1117',
#  'm107']

# %%
liked_movies.loc[liked_movies['movie_id'].isin(u195list)]['user_id'].value_counts()
# Out:
# u195    22
# u302    13
# u757    12
# u415    12
# u275    12
#         ..
# u426     1
# u761     1
# u832     1
# u420     1
# u371     1
# Name: user_id, Length: 702, dtype: int64

# %%
G=nx.from_pandas_edgelist(liked_movies, 'user_id', 'movie_id',['rating'])

# %%
#  G=nx.read_adjlist("/content/drive/MyDrive/Portfolio/Github-Recommender-System-master/Githubdataset.txt")
# G.add_edges_from([('u1671', 'p77085'), ('u1671', 'p101'), ('u9370', 'p80829'), ('u9370', 'p24399'), ('u31046', 'p660'), ('u10435', 'p72873'), ('u14401', 'p66726'), ('u4418', 'p45105'), ('u347', 'p6666'), ('u347', 'p995'), ('u347', 'p377'), ('u347', 'p1713'), ('u347', 'p11626'), ('u347', 'p2748'), ('u347', 'p1984'), ('u347', 'p355'), ('u347', 'p285'), ('u347', 'p607'), ('u9304', 'p106495'), ('u9304', 'p76342'), ('u6979', 'p3270'), ('u6979', 'p1455'), ('u28678', 'p43125'), ('u201', 'p79156'), ('u201', 'p214'), ('u201', 'p374'), ('u201', 'p223'), ('u201', 'p1109'), ('u201', 'p709'), ('u201', 'p7944'), ('u201', 'p37863'), ('u201', 'p6323'), ('u21', 'p26797'), ('u21', 'p9717'), ('u21', 'p44164'), ('u21', 'p12646'), ('u21', 'p31355'), ('u21', 'p3273'), ('u21', 'p17699'), ('u21', 'p2045'), ('u21', 'p48949'), ('u21', 'p20947'), ('u21', 'p11138'), ('u21', 'p2542'), ('u21', 'p557'), ('u21', 'p22118'), ('u21', 'p28811'), ('u21', 'p35264'), ('u21', 'p4630'), ('u21', 'p5820'), ('u21', 'p64681'), ('u21', 'p1496'), ('u21', 'p5395'), ('u21', 'p12244'), ('u21', 'p16236'), ('u21', 'p28114'), ('u21', 'p7070'), ('u21', 'p
'), ('u14696', 'p259'), ('u21389', 'p38766'), ('u9556', 'p11937'), ('u3606', 'p481'), ('u3606', 'p2692'), ('u3606', 'p1796'), ('u3606', 'p5346'), ('u4546', 'p270'), ('u5158', 'p3478'), ('u5158', 'p405'), ('u5158', 'p4351'), ('u5158', 'p604'), ('u16225', 'p40132'), ('u13302', 'p14488'), ('u13302', 'p11698'), ('u13302', 'p2514'), ('u13302', 'p725'), ('u41158', 'p79126'), ('u7456', 'p1831'), ('u7456', 'p104011'), ('u7456', 'p154'), ('u7456', 'p6841'), ('u7456', 'p548'), ('u7456', 'p15'), ('u7456', 'p21553'), ('u7456', 'p1899'), ('u22294', 'p30623'), ('u21630', 'p69836'), ('u11878', 'p50810'), ('u11878', 'p181'), ('u5639', 'p21506'), ('u5639', 'p30597'), ('u2022', 'p46451'), ('u2022', 'p19037'), ('u2022', 'p9548'), ('u2022', 'p77986'), ('u2022', 'p12741'), ('u2022', 'p1108'), ('u2022', 'p113832'), ('u2022', 'p5981'), ('u2022', 'p354'), ('u2022', 'p9211'), ('u2022', 'p4596'), ('u44557', 'p119231'), ('u11781', 'p4946'), ('u9239', 'p1163'), ('u19686', 'p11069'), ('u94', 'p2895'), ('u94', 'p285'), ('u94', 'p4139'), ('u94', 'p6713'), ('u94', 'p7921'), ('u94', 'p746'), ('u94', 'p2053'), ('u94', 'p39425'), ('u94', 'p23810'), ('u94', 'p4930'), ('u94', 'p1208'), ('u94', 'p19861'), ('u94', 'p33205'), ('u94', 'p3890'), ('u94', 'p3421'), ('u94', 'p78590'), ('u94', 'p18455'), ('u94', 'p3609'), ('u4036', 'p8538'), ('u4036', 'p3010')])

# %%
print(G)
# Out:
# Graph with 2389 nodes and 55375 edges

# %%
type(G)
# Out:
# networkx.classes.graph.Graph

# %%
len(G.nodes())
# Out:
# 2389

# %%
len(G.edges())
# Out:
# 55375

# %%
# for nodes in G.nodes():
#   if(nodes[:1]=='p'):
#     G.nodes[nodes]['bipartite'] = 'projects'
#   else:
#     G.nodes[nodes]['bipartite'] = 'users'

# %%
for nodes in G.nodes():
  if(nodes[:1]=='m'):
    G.nodes[nodes]['bipartite'] = 'movie'
  else:
    G.nodes[nodes]['bipartite'] = 'user'

# %%
G.nodes(data=True)
# Out:
# NodeDataView({'u195': {'bipartite': 'user'}, 'm110': {'bipartite': 'movie'}, 'm24': {'bipartite': 'movie'}, 'm381': {'bipartite': 'movie'}, 'm152': {'bipartite': 'movie'}, 'm285': {'bipartite': 'movie'}, 'm844': {'bipartite': 'movie'}, 'm237': {'bipartite': 'movie'}, 'm380': {'bipartite': 'movie'}, 'm305': {'bipartite': 'movie'}, 'm7': {'bipartite': 'movie'}, 'm654': {'bipartite': 'movie'}, 'm691': {'bipartite': 'movie'}, 'm1021': {'bipartite': 'movie'}, 'm284': {'bipartite': 'movie'}, 'm392': {'bipartite': 'movie'}, 'm662': {'bipartite': 'movie'}, 'm427': {'bipartite': 'movie'}, 'm410': {'bipartite': 'movie'}, 'm1006': {'bipartite': 'movie'}, 'm66': {'bipartite': 'movie'}, 'm1117': {'bipartite': 'movie'}, 'm107': {'bipartite': 'mov
'm256': {'bipartite': 'movie'}, 'm274': {'bipartite': 'movie'}, 'm234': {'bipartite': 'movie'}, 'm743': {'bipartite': 'movie'}, 'm286': {'bipartite': 'movie'}, 'm268': {'bipartite': 'movie'}, 'm318': {'bipartite': 'movie'}, 'm18': {'bipartite': 'movie'}, 'm1513': {'bipartite': 'movie'}, 'm1250': {'bipartite': 'movie'}, 'u295': {'bipartite': 'user'}, 'm221': {'bipartite': 'movie'}, 'm273': {'bipartite': 'movie'}, 'm143': {'bipartite': 'movie'}, 'm0': {'bipartite': 'movie'}, 'm245': {'bipartite': 'movie'}, 'm193': {'bipartite': 'movie'}, 'm31': {'bipartite': 'movie'}, 'm180': {'bipartite': 'movie'}, 'm19': {'bipartite': 'movie'}, 'm426': {'bip ...

# %%
# Define get_nodes_from_partition()
def get_nodes_from_partition(G,partition):
    # Initialize an empty list for nodes to be returned
    nodes = []
    # Iterate over each node in the graph G
    for n in G.nodes():
        # Check that the node belongs to the particular partition
        if G.nodes[n]['bipartite'] == partition:
            # If so, append it to the list of nodes
            nodes.append(n)
    return nodes

# Print the number of nodes in the 'users' partition
print(len(get_nodes_from_partition(G, 'user')))
print(len(get_nodes_from_partition(G, 'movie')))
# Out:
# 942
# 1447

# %%
# Import matplotlib
import matplotlib.pyplot as plt

# Get the 'users' nodes: user_nodes
user_nodes = get_nodes_from_partition(G,'user')

# Compute the degree centralities: dcs
dcs = nx.degree_centrality(G)

# Get the degree centralities for user_nodes: user_dcs
user_dcs = [dcs[n] for n in user_nodes]

# Plot the degree distribution of users_dcs
plt.yscale('log')
plt.hist(user_dcs, bins=20)
plt.show()

# %%
# Import matplotlib
import matplotlib.pyplot as plt

# Get the 'users' nodes: user_nodes
project_nodes = get_nodes_from_partition(G,'movie')

# Compute the degree centralities: dcs
dcs = nx.degree_centrality(G)

# Get the degree centralities for user_nodes: user_dcs
project_dcs = [dcs[n] for n in project_nodes]

# Plot the degree distribution of users_dcs
plt.yscale('log')
plt.hist(project_dcs, bins=20)
plt.show()

# %%
def shared_partition_nodes(G, node1, node2):
    # Check that the nodes belong to the same partition
    assert G.nodes[node1]['bipartite'] == G.nodes[node2]['bipartite']

    # Get neighbors of node 1: nbrs1
    nbrs1 = G.neighbors(node1)
    # Get neighbors of node 2: nbrs2
    nbrs2 = G.neighbors(node2)

    # Compute the overlap using set intersections
    overlap = set(nbrs1).intersection(nbrs2)
    return overlap

# Print the number of shared repositories between users 'u7909' and 'u2148'
print(len(shared_partition_nodes(G, 'u195', 'u302')))
# Out:
# 13

# %%
G.edges(data=True)
# Out:
# EdgeDataView([('u195', 'm110', {'rating': 4}), ('u195', 'm24', {'rating': 4}), ('u195', 'm381', {'rating': 4}), ('u195', 'm152', {'rating': 5}), ('u195', 'm285', {'rating': 5}), ('u195', 'm844', {'rating': 4}), ('u195', 'm237', {'rating': 4}), ('u195', 'm380', {'rating': 4}), ('u195', 'm305', {'rating': 4}), ('u195', 'm7', {'rating': 5}), ('u195', 'm654', {'rating': 5}), ('u195', 'm691', {'rating': 5}), ('u195', 'm1021', {'rating': 4}), ('u195', 'm284', {'rating': 5}), ('u195', 'm392', {'rating': 4}), ('u195', 'm662', {'rating': 5}), ('u195', 'm427', {'rating': 4}), ('u195', 'm410', {'rating': 4}), ('u195', 'm1006', {'rating': 4}), ('u195', 'm66', {'rating': 5}), ('u195', 'm1117', {'rating': 4}), ('u195', 'm107', {'rating': 4}), ('m110', 'u305', {'rating': 4}), ('m110', 'u270', {'rating': 4}), ('m110', 'u0', {'rating': 5}), ('m110', 'u1', {'rating': 4}), ('m110', 'u496', {'rating': 4}), ('m110', 'u415', {'rating': 4}), ('m110', 'u770', {'rating': 4}), ('m110', 'u532', {'rating': 4}), ('m110', 'u485', {'rating': 4}), ('m110', 'u12', {'rating': 5}), ('m110', 'u706', {'rating': 4}), ('m110', 'u499', {'rating': 4}), ('m110', 'u720', {'rating': 4}), ('m110', 'u177', {'rating': 4}), ('m110', 'u276', {'rating': 4}), ('m110', 'u344', {'rating': 4}), ('m110', 'u42', {'rating': 4}), ('m110', 'u513', {'rating': 5}), ('m110', 'u14', {'rating': 4}), ('m110', 'u633', {'rating': 4}), ('m110', 'u449', {'rating': 4}), ('m110', 'u554', {'rating': 4}), ('m110', 'u93', {'rating': 4}), ('m110', 'u542', {'rating': 4}), ('m110', 'u326', {'rating': 4}), ('m110', 'u51', {'rating': 4}), ('m110', 'u716', {'rating': 4}), ('m110', 'u400', {'rating': 4}), ('m110', 'u473', {'rating': 4}), ('m110', 'u668', {'rating': 4}), ('m110', 'u746', {'rating': 4}), ('m110', 'u150', {'rating': 4}), ('m110', 'u837', {'rating': 4}), ('m110', 'u157', {'rating': 4}), ('m110', 'u656', {'rating': 5}), ('m110', 'u523', {'rating': 5}), ('m110', 'u653', {'rating': 4}), ('m110', 'u769', {'rating': 5}), ('m110', 'u879', {'rating': 4}), ('m110', 'u184', {'rating': 4}), ('m110', 'u550', {'rating': 5}), ('m110', 'u918', {'rating': 4}), ('m110', 'u343', {'rating': 4}), ('m110', 'u313', {'rating': 4}), ('m110', 'u467', {'rating': 4}), ('m110', 'u704', {'rating': 4}), ('m110', 'u647', {'rating': 5}), ('m110', 'u243', {'rating': 4}), ('m110', 'u235', {'rating': 4}), ('m110', 'u151', {'rating': 5}), ('m110', 'u10', {'rating': 4}), ('m110', 'u58', {'rating': 4}), ('m110', 'u483', {'rating': 4}), ('m110', 'u94', {'rating': 4}), ('m110', 'u592', {'rating': 5}), ('m110', 'u898', {'rating': 4}), ('m110', 'u915', {'rating': 4}), ('m110', 'u942', {'rating': 4}), ('m110', 'u877', {'rating': 4}), ('m110', 'u129', {'rating': 5}), ('m110', 'u293', {'rating': 4}), ('m110', 'u664', {'rating': 4}), ('m110', 'u594', {'rating': 4}), ('m110', 'u935', {'rating': 4}), ('m110', 'u249', {'rating': 4}), ('m110', 'u487', {'rating': 4}), ('m110', 'u57', {'rating': 4}), ('m110', 'u552', {'rating': 4}), ('m110', 'u81', {'rating': 4}), ('m110', 'u861', {'rating': 5}), ('m110', 'u795', {'rating': 4}), ('m110', 'u822', {'rating': 4}), ('m110', 'u715', {'rating': 4}), ('m110', 'u642', {'rating': 4}), ('m110', 'u478', {'rating': 4}), ('m110', 'u137', {'rating': 4}), ('m110', 'u621', {'rating': 4}), ('m110', 'u83', {'rating': 4}), ('m110', 'u279', {'rating': 4}), ('m110', 'u291', {'rating': 4}), ('m110', 'u63', {'rating': 4}), ('m110', 'u108', {'rating': 4}), ('m110', 'u605', {'rating': 4}), ('m110', 'u628', {'rating': 5}), ('m110', 'u576', {'rating': 4}), ('m110', 'u435', {'rating': 4}), ('m110', 'u553', {'rating': 4}), ('m110', 'u683', {'rating': 4}), ('m110', 'u785', {'rating': 5}), ('m110', 'u285', {'rating': 5}), ('m110', 'u629', {'rating': 5}), ('m110', 'u886', {'rating': 5}), ('m110', 'u158', {'rating': 4}), ('m110', 'u118', {'rating': 5}), ('m110', 'u173', {'rating': 5}), ('m110', 'u261', {'rating': 4}), ('m110', 'u86', {'rating': 4}), ('m110', 'u884', {'rating': 4}), ('m110', 'u759', {'rating': 4}), ('m110', 'u ...

# %%
def user_similarity(G, user1, user2, proj_nodes):
    # Check that the nodes belong to the 'users' partition
    assert G.nodes[user1]['bipartite'] == 'user'
    assert G.nodes[user2]['bipartite'] == 'user'

    # Get the set of nodes shared between the two users
    shared_nodes = shared_partition_nodes(G, user1, user2)

    # Return the fraction of nodes in the projects partition
    return len(shared_nodes) / len(proj_nodes)

# Compute the similarity score between users 'u4560' and 'u1880'
project_nodes = get_nodes_from_partition(G, 'movie')
similarity_score = user_similarity(G, 'u195', 'u302', project_nodes)

print(similarity_score)
# Out:
# 0.008984105044920525

# %%
def user_simrank(G, user1, user2):
    # Check that the nodes belong to the 'users' partition
    assert G.nodes[user1]['bipartite'] == 'user'
    assert G.nodes[user2]['bipartite'] == 'user'

    return nx.simrank_similarity(G, source=user1, target=user2)

# %%
simrank_score = user_simrank(G, 'u195', 'u302')

print(simrank_score)
# Out:
# 0.018258093308406116

# %%
from collections import defaultdict

def most_similar_users(G, user, user_nodes, proj_nodes):
    # Data checks
    assert G.nodes[user]['bipartite'] == 'user'

    # Get other nodes from user partition
    user_nodes = set(user_nodes)
    user_nodes.remove(user)

    # Create the dictionary: similarities
    similarities = defaultdict(list)
    for n in user_nodes:
        similarity = user_similarity(G, user, n, proj_nodes)
        similarities[similarity].append(n)

    # Compute maximum similarity score: max_similarity
    max_similarity = max(similarities.keys())

    # Return list of users that share maximal similarity
    # return similarities[max_similarity]
    sorted_sim = {k: v for k, v in sorted(similarities.items(), key=lambda item: item[0],reverse=True)}
    sim_list = []
    for i in sorted_sim:
        sim_list.append(sorted_sim[i])
        simlist = [item for sublist in sim_list for item in sublist]
    return simlist

# %%
user_nodes = get_nodes_from_partition(G, 'user')
project_nodes = get_nodes_from_partition(G, 'movie')
sim_users_ranked = most_similar_users(G, 'u195', user_nodes, project_nodes)
print(sim_users_ranked)
# Output - ['u5453', 'u17446']
# Out:
u525', 'u743', 'u776', 'u453', 'u315', 'u585', 'u277', 'u237', 'u188', 'u477', 'u364', 'u849', 'u921', 'u911', 'u561', 'u937', 'u658', 'u675', 'u59', 'u219', 'u749', 'u889', 'u53', 'u70', 'u431', 'u562', 'u225', 'u610', 'u617', 'u759', 'u589', 'u423', 'u232', 'u433', 'u828', 'u167', 'u402', 'u29', 'u412', 'u271', 'u923', 'u48', 'u905', 'u390', 'u540', 'u704', 'u755', 'u719', 'u636', 'u200', 'u246', 'u286', 'u535', 'u524', 'u557', 'u140', 'u18', 'u718', 'u227', 'u840', 'u11', 'u876', 'u354', 'u370', 'u265', 'u30', 'u250', 'u507', 'u747', 'u283', 'u187', 'u211', 'u122', 'u805', 'u875', 'u446', 'u730', 'u153', 'u241', 'u714', 'u727', 'u862', 'u186', 'u249', 'u662', 'u425', 'u656', 'u797', 'u737', 'u43', 'u901', 'u793', 'u144', 'u479', 'u798', 'u802', 'u458', 'u707', 'u328', 'u253', 'u75', 'u692', 'u470', 'u490', 'u76', 'u824', 'u97', 'u309', 'u258', 'u348', 'u673', 'u770', 'u191', 'u47', 'u878', 'u120', 'u67', 'u421', 'u154', 'u419', 'u252', 'u659', 'u732', 'u474', 'u938', 'u119', 'u158', 'u324', 'u818', 'u644', 'u172', 'u814', 'u111', 'u629', 'u537', 'u908', 'u565', 'u609', 'u927', 'u115', 'u604', 'u711', 'u930', 'u835', 'u175', 'u866', 'u179', 'u820', 'u703', 'u198', 'u476', 'u222', 'u229', 'u418', 'u769', 'u519', 'u700', 'u422', 'u161', 'u138', 'u336', 'u594', 'u383', 'u363', 'u640', 'u744', 'u698', 'u754', 'u571', 'u821', 'u626', 'u580', 'u146', 'u857', 'u661', 'u779', 'u3 ...

# %%
top10_sim_users = sim_users_ranked[:10]
top10_sim_users
# Out:
# ['u302', 'u757', 'u415', 'u307', 'u275', 'u150', 'u93', 'u473', 'u326', 'u341']

# %%
# def most_simranked_users(G, user, user_nodes):
#     # Data checks
#     assert G.nodes[user]['bipartite'] == 'user'

#     # Get other nodes from user partition
#     # user_nodes = set(user_nodes)
#     # user_nodes.remove(user)

#     # Create the dictionary: similarities
#     similarities = defaultdict(list)
#     for n in user_nodes:
#         similarity = user_simrank(G, user, n)
#         similarities[similarity].append(n)

#     # Compute maximum similarity score: max_similarity
#     # max_similarity = sorted(max_similarity.items(), key=lambda item: item[1])

#     # Return list of users that share maximal similarity
#     return similarities

# %%
# user_nodes = get_nodes_from_partition(G, 'user')
# project_nodes = get_nodes_from_partition(G, 'movie')

# print(most_simranked_users(G, 'u195', top10_sim_users))
# # Output - ['u5453', 'u17446']

# %%
def rec_movies_from_most_sim_user(G, from_user, to_user):
    # Get the set of repositories that from_user has contributed to

    from_repos = set(G.neighbors(from_user))
    # Get the set of repositories that to_user has contributed to
    to_repos = set(G.neighbors(to_user))

    # Identify repositories that the from_user is connected to that the to_user is not connected to
    return list(from_repos.difference(to_repos))

# Print the repositories to be recommended
top_user_movie_recs = rec_movies_from_most_sim_user(G, 'u302', 'u195')
top_user_movie_recs

# %%
import collections

# %%
def rec_movies_from_most_sim_users_list(G, from_users, to_user):
    # Get the set of repositories that from_user has contributed to
    from_users_movies = []
    for u in from_users:
        from_users_movies.append(G.neighbors(u))
    u_movies = [item for sublist in from_users_movies for item in sublist]
    # counts = sorted(collections.Counter(u_movies),reverse=True)
    from_repos = set(u_movies)
    # Get the set of repositories that to_user has contributed to
    to_repos = set(G.neighbors(to_user))

    # Identify repositories that the from_user is connected to that the to_user is not connected to
    # return list(from_repos.difference(to_repos))
    return u_movies
# Print the repositories to be recommended
sim_users_movie_recs = rec_movies_from_most_sim_users_list(G, top10_sim_users, 'u195')
sim_users_movie_recs

# %% [markdown]
# # ToDo
# ### Finish algorithm for returning movies from most similar users specific to our user

# %%
countm = collections.Counter(movie_recs)
countm
# Out:
# Counter({'m0': 7,
#          'm1': 2,
#          'm10': 8,
#          'm100': 1,
#          'm1000': 1,
#          'm1005': 1,
#          'm1006': 6,
#          'm1008': 2,
#          'm1009': 1,
#          'm1010': 3,
#          'm1011': 5,
#          'm1013': 1,
#          'm1015': 2,
#          'm1018': 3,
#          'm1019': 1,
#          'm1020': 2,
#          'm1021': 1,
#          'm1022': 1,
#          'm1033': 1,
#          'm1038': 3,
#          'm1043': 1,
#          'm1044': 3,
#          'm1045': 2,
#          'm1047': 2,
#          'm1049': 2,
#          'm1051': 1,
#          'm1052': 1,
#          'm1055': 1,
#          'm1057': 2,
#          'm106': 2,
#          'm1062': 1,
#          'm1064': 2,
#          'm1066': 1,
#          'm1068': 1,
#          'm1069': 2,
#          'm107': 2,
#          'm1070': 1,
#          'm1072': 2,
#          'm1073': 1,
#          'm1074': 1,
#          'm108': 3,
#          'm1084': 1,
#          'm1096': 1,
#          'm1097': 4,
#          'm1099': 1,
#          'm11': 9,
#          'm110': 5,
#          'm1100': 2,
#          'm1102': 1,
#          'm1108': 2,
#          'm1109': 1,
#          'm1110': 1,
#          'm1112': 1,
#          'm1117': 3,
#          'm1118': 2,
#          'm1122': 1,
#          'm1123': 1,
#          'm1127': 1,
#          'm1128': 1,
#          'm113': 2,
#          'm1130': 1,
#          'm1132': 1,
#          'm1134': 3,
#          'm1135': 1,
#          'm1139': 1,
#          'm1141': 2,
#          'm1142': 1,
#          'm1146': 3,
#          'm115': 4,
#          'm1151': 1,
#          'm1152': 1,
#          'm1158': 1,
#          'm1159': 1,
#          'm116': 4,
#          'm1167': 1,
#          'm1168': 1,
#          'm1169': 2,
#          'm1171': 2,
#          'm1186': 1,
#          'm1187': 1,
#          'm1188': 1,
#          'm1196': 2,
#          'm1198': 1,
#          'm1199': 1,
#          'm12': 4,
#          'm120': 4,
#          'm1202': 1,
#          'm121': 4,
#          'm1210': 1,
#          'm1216': 1,
#          'm1217': 4,
#          'm1218': 1,
#          'm1219': 1,
#          'm122': 4,
#          'm1220': 2,
#          'm1222': 1,
#          'm1225': 2,
#          'm123': 8,
#          'm1239': 1,
#          'm124': 3,
#          'm125': 2,
#          'm126': 8,
#          'm1261': 1,
#          'm1263': 2,
#          'm1266': 1,
#          'm1268': 1,
#          'm127': 3,
#          'm128': 5,
#          'm1282': 1,
#          'm1285': 3,
#          'm1297': 1,
#          'm1298': 1,
#          'm13': 7,
#          'm130': 5,
#          'm1300': 1,
#          'm131': 7,
#          'm132': 4,
#          'm133': 8,
#          'm134': 6,
#          'm135': 3,
#          'm136': 4,
#          'm1367': 1,
#          'm138': 2,
#          'm139': 1,
#          'm1399': 1,
#          'm14': 3,
#          'm140': 3,
#          'm1403': 1,
#          'm141': 1,
#          'm1410': 1,
#          'm142': 10,
#          'm1420': 2,
#          'm1425': 1,
#          'm143': 6,
#          'm1455': 1,
#          'm146': 4,
#          'm147': 1,
#          'm148': 1,
#          'm1481': 1,
#          'm1482': 1,
#          'm149': 6,
#          'm150': 7,
#          'm1502': 1,
#          'm151': 4,
#          'm1514': 1,
#          'm1515': 1,
#          'm152': 8,
#          'm153': 7,
#          'm1539': 1,
#          'm154': 1,
#          'm155': 7,
#          'm156': 4,
#          'm159': 6,
#          'm1593': 1,
#          'm16': 3,
#          'm160': 3,
#          'm161': 2,
#          'm162': 3,
#          'm163': 5,
#          'm167': 8,
#          'm168': 4,
#          'm169': 5,
#          'm170': 6,
#          'm171': 9,
#          'm172': 8,
#          'm173': 9,
#          'm174': 7,
#          'm175': 8,
#          'm176': 3,
#          'm177': 5,
#          'm178': 7,
#          'm179': 5,
#          'm180': 9,
#          'm181': 8,
#          'm182': 7,
#          'm183': 5,
#          'm184': 8,
#          'm185': 7,
#          'm186': 6,
#          'm187': 4,
#          'm188': 3,
#          'm189': 3,
#          'm19': 1,
#          'm190': 8,
#          'm191': 7,
#          'm192': 5,
#          'm193': 6,
#          'm194': 7,
#          'm195': 7,
#          'm196': 6,
#          'm197': 4,
#          'm198': 4,
#          'm199': 7,
#          'm200': 5,
#          'm201': 7,
#          'm202': 6,
#          'm203': 10,
#          'm204': 1,
#          'm205': 2,
#          'm206': 2,
#          'm207': 6,
#          'm208': 10,
#          'm209': 8,
#          'm21': 7,
#          'm210': 6,
#          'm211': 3,
#          'm212': 5,
#          'm213': 2,
#          'm214': 6,
#          'm215': 6,
#          'm216': 3,
#          'm217': 5,
#          'm218': 5,
#          'm219': 1,
#          'm22': 8,
#          'm220': 2,
#          'm221': 4,
#          'm222': 8,
#          'm223': 2,
#          'm225': 3,
#          'm226': 4,
#          'm227': 5,
#          'm229': 5,
#          'm23': 5,
#          'm230': 1,
#          'm231': 3,
#          'm232': 1,
#          'm233': 8,
#          'm234': 4,
#          'm235': 2,
#          'm236': 6,
#          'm237': 10,
#          'm238': 2,
#          'm239': 1,
#          'm24': 7,
#          'm240': 5,
#          'm241': 1,
#          'm243': 1,
#          'm245': 6,
#          'm247': 6,
#          'm248': 3,
#          'm249': 5,
#          'm25': 3,
#          'm250': 3,
#          'm251': 2,
#          'm252': 1,
#          'm254': 5,
#          'm256': 5,
#          'm257': 7,
#          'm26': 1,
#          'm261': 3,
#          'm264': 5,
#          'm267': 5,
#          'm268': 4,
#          'm269': 3,
#          'm27': 6,
#          'm270': 2,
#          'm271': 3,
#          'm272': 4,
#          'm273': 3,
#          'm274': 4,
#          'm275': 4,
#          'm276': 2,
#          'm280': 1,
#          'm281': 3,
#          'm282': 1,
#          'm283': 5,
#          'm284': 4,
#          'm285': 7,
#          'm286': 4,
#          'm287': 7,
#          'm289': 3,
#          'm29': 1,
#          'm290': 3,
#          'm291': 1,
#          'm292': 7,
#          'm293': 4,
#          'm294': 1,
#          'm296': 2,
#          'm297': 5,
#          'm299': 3,
#          'm3': 10,
#          'm30': 4,
#          'm300': 4,
#          'm301': 6,
#          'm302': 3,
#          'm303': 1,
#          'm304': 2,
#          'm306': 1,
#          'm309': 1,
#          'm31': 4,
#          'm310': 1,
#          'm312': 6,
#          'm314': 3,
#          'm315': 3,
#          'm316': 5,
#          'm317': 8,
#          'm318': 5,
#          'm319': 2,
#          'm32': 4,
#          'm320': 1,
#          'm321': 1,
#          'm323': 2,
#          'm325': 1,
#          'm326': 2,
#          'm327': 2,
#          'm330': 3,
#          'm331': 3,
#          'm332': 3,
#          'm333': 1,
#          'm337': 2,
#          'm338': 1,
#          'm339': 3,
#          'm341': 1,
#          'm342': 2,
#          'm343': 1,
#          'm344': 2,
#          'm345': 4,
#          'm346': 3,
#          'm349': 1,
#          'm351': 1,
#          'm352': 1,
#          'm353': 2,
#          'm354': 1,
#          'm355': 3,
#          'm356': 8,
#          'm361': 1,
#          'm363': 1,
#          'm365': 1,
#          'm366': 6,
#          'm370': 1,
#          'm371': 2,
#          'm372': 1,
#          'm377': 4,
#          'm378': 1,
#          'm379': 3,
#          'm380': 6,
#          'm381': 3,
#          'm383': 1,
#          'm384': 6,
#          'm385': 2,
#          'm386': 2,
#          'm389': 1,
#          'm391': 2,
#          'm392': 5,
#          'm395': 3,
#          'm398': 2,
#          'm4': 1,
#          'm40': 1,
#          'm400': 1,
#          'm401': 4,
#          'm402': 4,
#          'm403': 3,
#          'm404': 4,
#          'm407': 5,
#          'm409': 4,
#          'm41': 5,
#          'm410': 5,
#          'm411': 1,
#          'm413': 3,
#          'm414': 1,
#          'm415': 2,
#          'm416': 1,
#          'm417': 3,
#          'm418': 7,
#          'm419': 5,
#          'm420': 5,
#          'm422': 8,
#          'm424': 7,
#          'm426': 8,
#          'm427': 7,
#          'm428': 3,
#          'm429': 4,
#          'm43': 4,
#          'm430': 3,
#          'm431': 4,
#          'm432': 8,
#          'm433': 2,
#          'm434': 7,
#          'm435': 4,
#          'm44': 3,
#          'm442': 5,
#          'm446': 6,
#          'm447': 4,
#          'm448': 1,
#          'm450': 5,
#          'm454': 3,
#          'm457': 2,
#          'm459': 1,
#          'm46': 7,
#          'm460': 5,
#          'm461': 5,
#          'm462': 5,
#          'm463': 3,
#          'm464': 1,
#          'm465': 2,
#          'm466': 3,
#          'm467': 2,
#          'm468': 6,
#          'm469': 3,
#          'm47': 3,
#          'm470': 3,
#          'm471': 1,
#          'm472': 3,
#          'm473': 6,
#          'm474': 8,
#          'm475': 2,
#          'm476': 2,
#          'm477': 3,
#          'm478': 6,
#          'm479': 6,
#          'm48': 2,
#          'm480': 3,
#          'm481': 6,
#          'm482': 6,
#          'm483': 5,
#          'm484': 2,
#          'm485': 4,
#          'm486': 4,
#          'm487': 3,
#          'm488': 3,
#          'm489': 3,
#          'm49': 8,
#          'm490': 4,
#          'm491': 1,
#          'm492': 1,
#          'm493': 3,
#          'm494': 1,
#          'm495': 5,
#          'm496': 3,
#          'm497': 5,
#          'm498': 3,
#          'm499': 1,
#          'm50': 2,
#          'm500': 5,
#          'm501': 3,
#          'm502': 1,
#          'm503': 4,
#          'm504': 3,
#          'm505': 6,
#          'm506': 5,
#          'm507': 4,
#          'm508': 6,
#          'm509': 3,
#          'm51': 3,
#          'm510': 2,
#          'm511': 3,
#          'm512': 1,
#          'm513': 7,
#          'm514': 2,
#          'm515': 2,
#          'm516': 4,
#          'm517': 4,
#          'm518': 2,
#          'm519': 4,
#          'm52': 3,
#          'm520': 1,
#          'm521': 1,
#          'm522': 6,
#          'm524': 5,
#          'm525': 4,
#          'm526': 4,
#          'm527': 3,
#          'm528': 3,
#          'm529': 2,
#          'm53': 2,
#          'm530': 5,
#          'm532': 2,
#          'm534': 1,
#          'm536': 3,
#          'm537': 1,
#          'm54': 5,
#          'm540': 1,
#          'm543': 1,
#          'm546': 3,
#          'm548': 4,
#          'm549': 4,
#          'm55': 9,
#          'm552': 1,
#          'm557': 5,
#          'm558': 4,
#          'm561': 1,
#          'm563': 1,
#          'm565': 4,
#          'm566': 2,
#          'm567': 5,
#          'm568': 1,
#          'm57': 7,
#          'm570': 1,
#          'm574': 1,
#          'm575': 2,
#          'm577': 3,
#          'm579': 1,
#          'm58': 1,
#          'm580': 3,
#          'm581': 4,
#          'm582': 1,
#          'm583': 4,
#          'm586': 2,
#          'm587': 6,
#          'm588': 2,
#          'm590': 2,
#          'm595': 1,
#          'm6': 9,
#          'm60': 1,
#          'm600': 1,
#          'm601': 2,
#          'm602': 9,
#          'm603': 1,
#          'm604': 2,
#          'm605': 2,
#          'm606': 3,
#          'm607': 2,
#          'm608': 3,
#          'm609': 2,
#          'm610': 3,
#          'm612': 1,
#          'm613': 3,
#          'm614': 2,
#          'm615': 4,
#          'm617': 2,
#          'm618': 2,
#          'm619': 1,
#          'm624': 2,
#          'm626': 1,
#          'm627': 5,
#          'm628': 4,
#          'm63': 8,
#          'm630': 2,
#          'm631': 1,
#          'm632': 4,
#          'm633': 4,
#          'm635': 2,
#          'm637': 1,
#          'm639': 3,
#          'm64': 4,
#          'm640': 2,
#          'm641': 3,
#          'm643': 1,
#          'm644': 1,
#          'm645': 3,
#          'm646': 3,
#          'm647': 2,
#          'm648': 3,
#          'm649': 5,
#          'm65': 4,
#          'm650': 5,
#          'm651': 7,
#          'm652': 4,
#          'm653': 7,
#          'm654': 9,
#          'm655': 2,
#          'm656': 7,
#          'm657': 3,
#          'm658': 4,
#          'm659': 3,
#          'm66': 2,
#          'm660': 3,
#          'm661': 2,
#          'm662': 5,
#          'm663': 3,
#          'm664': 2,
#          'm67': 4,
#          'm670': 1,
#          'm672': 2,
#          'm674': 1,
#          'm675': 1,
#          'm678': 2,
#          'm68': 6,
#          'm683': 6,
#          'm684': 3,
#          'm685': 4,
#          'm688': 1,
#          'm689': 2,
#          'm69': 8,
#          'm690': 1,
#          'm691': 5,
#          'm692': 3,
#          'm695': 1,
#          'm696': 1,
#          'm698': 5,
#          'm7': 9,
#          'm70': 5,
#          'm702': 1,
#          'm704': 4,
#          'm706': 3,
#          'm707': 4,
#          'm708': 5,
#          'm709': 3,
#          'm71': 2,
#          'm711': 2,
#          'm712': 1,
#          'm714': 5,
#          'm717': 1,
#          'm719': 1,
#          'm72': 1,
#          'm720': 1,
#          'm722': 1,
#          'm723': 2,
#          'm726': 2,
#          'm728': 3,
#          'm73': 1,
#          'm731': 5,
#          'm734': 7,
#          'm735': 2,
#          'm736': 3,
#          'm738': 3,
#          'm740': 3,
#          'm741': 5,
#          'm743': 1,
#          'm745': 7,
#          'm746': 2,
#          'm747': 1,
#          'm749': 3,
#          'm75': 3,
#          'm750': 2,
#          'm752': 1,
#          'm753': 1,
#          'm754': 1,
#          'm76': 3,
#          'm760': 1,
#          'm761': 1,
#          'm762': 2,
#          'm764': 1,
#          'm769': 4,
#          'm77': 1,
#          'm771': 1,
#          'm772': 1,
#          'm774': 1,
#          'm777': 1,
#          'm779': 2,
#          'm78': 8,
#          'm780': 1,
#          'm781': 1,
#          'm788': 2,
#          'm789': 3,
#          'm79': 1,
#          'm791': 6,
#          'm793': 1,
#          'm8': 9,
#          'm80': 8,
#          'm804': 4,
#          'm805': 4,
#          'm806': 1,
#          'm81': 6,
#          'm810': 2,
#          'm811': 1,
#          'm812': 4,
#          'm814': 2,
#          'm817': 1,
#          'm819': 1,
#          'm82': 4,
#          'm820': 1,
#          'm821': 1,
#          'm823': 1,
#          'm824': 1,
#          'm826': 1,
#          'm830': 2,
#          'm834': 1,
#          'm835': 1,
#          'm836': 2,
#          'm839': 1,
#          'm84': 1,
#          'm841': 1,
#          'm842': 1,
#          'm843': 1,
#          'm844': 4,
#          'm846': 2,
#          'm847': 2,
#          'm85': 4,
#          'm852': 2,
#          'm853': 1,
#          'm855': 2,
#          'm86': 4,
#          'm863': 1,
#          'm864': 2,
#          'm865': 1,
#          'm87': 5,
#          'm872': 1,
#          'm874': 2,
#          'm88': 5,
#          'm886': 1,
#          'm89': 2,
#          'm894': 2,
#          'm895': 2,
#          'm897': 1,
#          'm9': 2,
#          'm90': 5,
#          'm901': 2,
#          'm91': 7,
#          'm914': 2,
#          'm915': 1,
#          'm916': 1,
#          'm917': 1,
#          'm918': 5,
#          'm92': 7,
#          'm920': 3,
#          'm921': 3,
#          'm922': 2,
#          'm923': 2,
#          'm927': 1,
#          'm928': 1,
#          'm935': 1,
#          'm938': 3,
#          'm94': 4,
#          'm941': 3,
#          'm942': 2,
#          'm944': 3,
#          'm948': 2,
#          'm95': 6,
#          'm952': 1,
#          'm954': 1,
#          'm955': 3,
#          'm958': 4,
#          'm959': 2,
#          'm96': 5,
#          'm960': 1,
#          'm961': 1,
#          'm962': 1,
#          'm964': 3,
#          'm965': 3,
#          'm967': 2,
#          'm968': 3,
#          'm97': 8,
#          'm970': 2,
#          'm971': 2,
#          'm978': 1,
#          'm979': 1,
#          'm98': 6,
#          'm99': 9,
#          'm992': 1,
#          'm996': 2})

# %%
counts = sorted(countm.items(), key=lambda x: x[1],reverse=True)
counts
# Out:
# [('m3', 10),
#  ('m142', 10),
#  ('m208', 10),
#  ('m203', 10),
#  ('m237', 10),
#  ('m602', 9),
#  ('m99', 9),
#  ('m180', 9),
#  ('m173', 9),
#  ('m171', 9),
#  ('m6', 9),
#  ('m55', 9),
#  ('m11', 9),
#  ('m7', 9),
#  ('m654', 9),
#  ('m8', 9),
#  ('m233', 8),
#  ('m97', 8),
#  ('m422', 8),
#  ('m426', 8),
#  ('m22', 8),
#  ('m78', 8),
#  ('m126', 8),
#  ('m317', 8),
#  ('m152', 8),
#  ('m10', 8),
#  ('m63', 8),
#  ('m356', 8),
#  ('m190', 8),
#  ('m133', 8),
#  ('m175', 8),
#  ('m172', 8),
#  ('m209', 8),
#  ('m474', 8),
#  ('m181', 8),
#  ('m49', 8),
#  ('m184', 8),
#  ('m167', 8),
#  ('m80', 8),
#  ('m69', 8),
#  ('m432', 8),
#  ('m222', 8),
#  ('m123', 8),
#  ('m0', 7),
#  ('m287', 7),
#  ('m24', 7),
#  ('m131', 7),
#  ('m150', 7),
#  ('m513', 7),
#  ('m194', 7),
#  ('m199', 7),
#  ('m418', 7),
#  ('m257', 7),
#  ('m201', 7),
#  ('m745', 7),
#  ('m182', 7),
#  ('m424', 7),
#  ('m285', 7),
#  ('m185', 7),
#  ('m46', 7),
#  ('m155', 7),
#  ('m21', 7),
#  ('m292', 7),
#  ('m178', 7),
#  ('m653', 7),
#  ('m91', 7),
#  ('m92', 7),
#  ('m434', 7),
#  ('m734', 7),
#  ('m195', 7),
#  ('m153', 7),
#  ('m13', 7),
#  ('m174', 7),
#  ('m57', 7),
#  ('m427', 7),
#  ('m656', 7),
#  ('m191', 7),
#  ('m651', 7),
#  ('m301', 6),
#  ('m473', 6),
#  ('m143', 6),
#  ('m245', 6),
#  ('m193', 6),
#  ('m236', 6),
#  ('m479', 6),
#  ('m207', 6),
#  ('m95', 6),
#  ('m384', 6),
#  ('m478', 6),
#  ('m215', 6),
#  ('m482', 6),
#  ('m68', 6),
#  ('m170', 6),
#  ('m366', 6),
#  ('m81', 6),
#  ('m214', 6),
#  ('m159', 6),
#  ('m186', 6),
#  ('m149', 6),
#  ('m380', 6),
#  ('m587', 6),
#  ('m505', 6),
#  ('m98', 6),
#  ('m202', 6),
#  ('m791', 6),
#  ('m1006', 6),
#  ('m481', 6),
#  ('m247', 6),
#  ('m134', 6),
#  ('m210', 6),
#  ('m508', 6),
#  ('m27', 6),
#  ('m446', 6),
#  ('m312', 6),
#  ('m683', 6),
#  ('m196', 6),
#  ('m468', 6),
#  ('m522', 6),
#  ('m450', 5),
#  ('m256', 5),
#  ('m87', 5),
#  ('m200', 5),
#  ('m240', 5),
#  ('m218', 5),
#  ('m918', 5),
#  ('m267', 5),
#  ('m163', 5),
#  ('m297', 5),
#  ('m442', 5),
#  ('m254', 5),
#  ('m407', 5),
#  ('m227', 5),
#  ('m567', 5),
#  ('m217', 5),
#  ('m506', 5),
#  ('m500', 5),
#  ('m483', 5),
#  ('m708', 5),
#  ('m557', 5),
#  ('m249', 5),
#  ('m96', 5),
#  ('m714', 5),
#  ('m530', 5),
#  ('m741', 5),
#  ('m183', 5),
#  ('m54', 5),
#  ('m283', 5),
#  ('m691', 5),
#  ('m460', 5),
#  ('m128', 5),
#  ('m420', 5),
#  ('m392', 5),
#  ('m90', 5),
#  ('m318', 5),
#  ('m650', 5),
#  ('m1011', 5),
#  ('m410', 5),
#  ('m41', 5),
#  ('m524', 5),
#  ('m649', 5),
#  ('m169', 5),
#  ('m419', 5),
#  ('m461', 5),
#  ('m731', 5),
#  ('m229', 5),
#  ('m212', 5),
#  ('m23', 5),
#  ('m627', 5),
#  ('m264', 5),
#  ('m110', 5),
#  ('m497', 5),
#  ('m495', 5),
#  ('m316', 5),
#  ('m177', 5),
#  ('m70', 5),
#  ('m698', 5),
#  ('m462', 5),
#  ('m88', 5),
#  ('m130', 5),
#  ('m662', 5),
#  ('m179', 5),
#  ('m192', 5),
#  ('m94', 4),
#  ('m517', 4),
#  ('m402', 4),
#  ('m293', 4),
#  ('m404', 4),
#  ('m558', 4),
#  ('m136', 4),
#  ('m234', 4),
#  ('m1097', 4),
#  ('m64', 4),
#  ('m67', 4),
#  ('m812', 4),
#  ('m197', 4),
#  ('m704', 4),
#  ('m507', 4),
#  ('m32', 4),
#  ('m429', 4),
#  ('m409', 4),
#  ('m401', 4),
#  ('m844', 4),
#  ('m435', 4),
#  ('m12', 4),
#  ('m146', 4),
#  ('m43', 4),
#  ('m286', 4),
#  ('m268', 4),
#  ('m151', 4),
#  ('m121', 4),
#  ('m490', 4),
#  ('m615', 4),
#  ('m516', 4),
#  ('m115', 4),
#  ('m581', 4),
#  ('m82', 4),
#  ('m275', 4),
#  ('m1217', 4),
#  ('m122', 4),
#  ('m652', 4),
#  ('m804', 4),
#  ('m221', 4),
#  ('m525', 4),
#  ('m116', 4),
#  ('m272', 4),
#  ('m519', 4),
#  ('m226', 4),
#  ('m198', 4),
#  ('m549', 4),
#  ('m447', 4),
#  ('m565', 4),
#  ('m284', 4),
#  ('m633', 4),
#  ('m526', 4),
#  ('m628', 4),
#  ('m345', 4),
#  ('m274', 4),
#  ('m377', 4),
#  ('m958', 4),
#  ('m65', 4),
#  ('m769', 4),
#  ('m120', 4),
#  ('m300', 4),
#  ('m685', 4),
#  ('m658', 4),
#  ('m86', 4),
#  ('m707', 4),
#  ('m156', 4),
#  ('m30', 4),
#  ('m548', 4),
#  ('m632', 4),
#  ('m485', 4),
#  ('m31', 4),
#  ('m431', 4),
#  ('m503', 4),
#  ('m168', 4),
#  ('m486', 4),
#  ('m805', 4),
#  ('m583', 4),
#  ('m187', 4),
#  ('m85', 4),
#  ('m132', 4),
#  ('m25', 3),
#  ('m231', 3),
#  ('m657', 3),
#  ('m76', 3),
#  ('m789', 3),
#  ('m108', 3),
#  ('m332', 3),
#  ('m16', 3),
#  ('m403', 3),
#  ('m248', 3),
#  ('m740', 3),
#  ('m1038', 3),
#  ('m738', 3),
#  ('m127', 3),
#  ('m160', 3),
#  ('m250', 3),
#  ('m1285', 3),
#  ('m417', 3),
#  ('m692', 3),
#  ('m395', 3),
#  ('m289', 3),
#  ('m469', 3),
#  ('m339', 3),
#  ('m225', 3),
#  ('m472', 3),
#  ('m261', 3),
#  ('m501', 3),
#  ('m269', 3),
#  ('m955', 3),
#  ('m331', 3),
#  ('m511', 3),
#  ('m684', 3),
#  ('m271', 3),
#  ('m176', 3),
#  ('m454', 3),
#  ('m140', 3),
#  ('m302', 3),
#  ('m211', 3),
#  ('m639', 3),
#  ('m290', 3),
#  ('m162', 3),
#  ('m314', 3),
#  ('m504', 3),
#  ('m921', 3),
#  ('m52', 3),
#  ('m379', 3),
#  ('m330', 3),
#  ('m315', 3),
#  ('m1018', 3),
#  ('m577', 3),
#  ('m546', 3),
#  ('m528', 3),
#  ('m413', 3),
#  ('m488', 3),
#  ('m480', 3),
#  ('m606', 3),
#  ('m273', 3),
#  ('m14', 3),
#  ('m749', 3),
#  ('m1146', 3),
#  ('m470', 3),
#  ('m346', 3),
#  ('m216', 3),
#  ('m430', 3),
#  ('m706', 3),
#  ('m659', 3),
#  ('m728', 3),
#  ('m124', 3),
#  ('m509', 3),
#  ('m281', 3),
#  ('m299', 3),
#  ('m1010', 3),
#  ('m941', 3),
#  ('m355', 3),
#  ('m709', 3),
#  ('m613', 3),
#  ('m135', 3),
#  ('m965', 3),
#  ('m381', 3),
#  ('m47', 3),
#  ('m648', 3),
#  ('m610', 3),
#  ('m641', 3),
#  ('m660', 3),
#  ('m608', 3),
#  ('m944', 3),
#  ('m487', 3),
#  ('m428', 3),
#  ('m580', 3),
#  ('m493', 3),
#  ('m920', 3),
#  ('m964', 3),
#  ('m489', 3),
#  ('m44', 3),
#  ('m1117', 3),
#  ('m466', 3),
#  ('m1134', 3),
#  ('m645', 3),
#  ('m663', 3),
#  ('m536', 3),
#  ('m1044', 3),
#  ('m188', 3),
#  ('m736', 3),
#  ('m646', 3),
#  ('m968', 3),
#  ('m75', 3),
#  ('m477', 3),
#  ('m496', 3),
#  ('m51', 3),
#  ('m189', 3),
#  ('m498', 3),
#  ('m938', 3),
#  ('m527', 3),
#  ('m463', 3),
#  ('m386', 2),
#  ('m672', 2),
#  ('m590', 2),
#  ('m630', 2),
#  ('m959', 2),
#  ('m664', 2),
#  ('m779', 2),
#  ('m830', 2),
#  ('m874', 2),
#  ('m220', 2),
#  ('m846', 2),
#  ('m385', 2),
#  ('m762', 2),
#  ('m1141', 2),
#  ('m1108', 2),
#  ('m1047', 2),
#  ('m1020', 2),
#  ('m89', 2),
#  ('m614', 2),
#  ('m1072', 2),
#  ('m66', 2),
#  ('m1225', 2),
#  ('m235', 2),
#  ('m337', 2),
#  ('m1015', 2),
#  ('m575', 2),
#  ('m750', 2),
#  ('m270', 2),
#  ('m586', 2),
#  ('m304', 2),
#  ('m323', 2),
#  ('m1045', 2),
#  ('m618', 2),
#  ('m996', 2),
#  ('m319', 2),
#  ('m138', 2),
#  ('m344', 2),
#  ('m894', 2),
#  ('m566', 2),
#  ('m532', 2),
#  ('m296', 2),
#  ('m107', 2),
#  ('m223', 2),
#  ('m655', 2),
#  ('m607', 2),
#  ('m901', 2),
#  ('m895', 2),
#  ('m864', 2),
#  ('m967', 2),
#  ('m836', 2),
#  ('m50', 2),
#  ('m391', 2),
#  ('m276', 2),
#  ('m326', 2),
#  ('m514', 2),
#  ('m415', 2),
#  ('m689', 2),
#  ('m53', 2),
#  ('m624', 2),
#  ('m327', 2),
#  ('m814', 2),
#  ('m1', 2),
#  ('m475', 2),
#  ('m467', 2),
#  ('m723', 2),
#  ('m661', 2),
#  ('m251', 2),
#  ('m711', 2),
#  ('m125', 2),
#  ('m398', 2),
#  ('m48', 2),
#  ('m476', 2),
#  ('m353', 2),
#  ('m238', 2),
#  ('m106', 2),
#  ('m746', 2),
#  ('m1118', 2),
#  ('m914', 2),
#  ('m726', 2),
#  ('m923', 2),
#  ('m971', 2),
#  ('m1220', 2),
#  ('m1057', 2),
#  ('m1263', 2),
#  ('m678', 2),
#  ('m647', 2),
#  ('m465', 2),
#  ('m1196', 2),
#  ('m588', 2),
#  ('m1064', 2),
#  ('m510', 2),
#  ('m161', 2),
#  ('m71', 2),
#  ('m515', 2),
#  ('m601', 2),
#  ('m640', 2),
#  ('m847', 2),
#  ('m529', 2),
#  ('m604', 2),
#  ('m852', 2),
#  ('m617', 2),
#  ('m609', 2),
#  ('m810', 2),
#  ('m518', 2),
#  ('m433', 2),
#  ('m855', 2),
#  ('m1420', 2),
#  ('m213', 2),
#  ('m342', 2),
#  ('m205', 2),
#  ('m942', 2),
#  ('m206', 2),
#  ('m635', 2),
#  ('m1169', 2),
#  ('m1171', 2),
#  ('m457', 2),
#  ('m484', 2),
#  ('m9', 2),
#  ('m1069', 2),
#  ('m735', 2),
#  ('m113', 2),
#  ('m371', 2),
#  ('m1100', 2),
#  ('m970', 2),
#  ('m605', 2),
#  ('m1049', 2),
#  ('m788', 2),
#  ('m922', 2),
#  ('m948', 2),
#  ('m1008', 2),
#  ('m978', 1),
#  ('m378', 1),
#  ('m230', 1),
#  ('m459', 1),
#  ('m79', 1),
#  ('m595', 1),
#  ('m761', 1),
#  ('m720', 1),
#  ('m448', 1),
#  ('m232', 1),
#  ('m777', 1),
#  ('m772', 1),
#  ('m574', 1),
#  ('m543', 1),
#  ('m561', 1),
#  ('m40', 1),
#  ('m1186', 1),
#  ('m1187', 1),
#  ('m383', 1),
#  ('m19', 1),
#  ('m349', 1),
#  ('m863', 1),
#  ('m291', 1),
#  ('m819', 1),
#  ('m1021', 1),
#  ('m1051', 1),
#  ('m1033', 1),
#  ('m411', 1),
#  ('m354', 1),
#  ('m579', 1),
#  ('m252', 1),
#  ('m570', 1),
#  ('m363', 1),
#  ('m310', 1),
#  ('m1000', 1),
#  ('m886', 1),
#  ('m351', 1),
#  ('m361', 1),
#  ('m1282', 1),
#  ('m372', 1),
#  ('m341', 1),
#  ('m1022', 1),
#  ('m352', 1),
#  ('m1142', 1),
#  ('m1084', 1),
#  ('m540', 1),
#  ('m1110', 1),
#  ('m1158', 1),
#  ('m241', 1),
#  ('m303', 1),
#  ('m563', 1),
#  ('m365', 1),
#  ('m139', 1),
#  ('m954', 1),
#  ('m793', 1),
#  ('m280', 1),
#  ('m754', 1),
#  ('m1216', 1),
#  ('m747', 1),
#  ('m219', 1),
#  ('m841', 1),
#  ('m338', 1),
#  ('m780', 1),
#  ('m719', 1),
#  ('m872', 1),
#  ('m141', 1),
#  ('m811', 1),
#  ('m865', 1),
#  ('m294', 1),
#  ('m619', 1),
#  ('m309', 1),
#  ('m154', 1),
#  ('m471', 1),
#  ('m760', 1),
#  ('m1132', 1),
#  ('m147', 1),
#  ('m26', 1),
#  ('m282', 1),
#  ('m928', 1),
#  ('m1159', 1),
#  ('m675', 1),
#  ('m806', 1),
#  ('m897', 1),
#  ('m722', 1),
#  ('m626', 1),
#  ('m820', 1),
#  ('m552', 1),
#  ('m534', 1),
#  ('m753', 1),
#  ('m839', 1),
#  ('m979', 1),
#  ('m764', 1),
#  ('m774', 1),
#  ('m325', 1),
#  ('m826', 1),
#  ('m688', 1),
#  ('m1019', 1),
#  ('m499', 1),
#  ('m917', 1),
#  ('m1261', 1),
#  ('m1052', 1),
#  ('m1188', 1),
#  ('m1073', 1),
#  ('m935', 1),
#  ('m414', 1),
#  ('m1151', 1),
#  ('m712', 1),
#  ('m1502', 1),
#  ('m1135', 1),
#  ('m537', 1),
#  ('m1167', 1),
#  ('m1399', 1),
#  ('m1482', 1),
#  ('m916', 1),
#  ('m1425', 1),
#  ('m1515', 1),
#  ('m1539', 1),
#  ('m1593', 1),
#  ('m4', 1),
#  ('m582', 1),
#  ('m58', 1),
#  ('m84', 1),
#  ('m670', 1),
#  ('m1005', 1),
#  ('m1410', 1),
#  ('m29', 1),
#  ('m73', 1),
#  ('m1168', 1),
#  ('m927', 1),
#  ('m674', 1),
#  ('m824', 1),
#  ('m612', 1),
#  ('m961', 1),
#  ('m821', 1),
#  ('m1139', 1),
#  ('m1403', 1),
#  ('m1455', 1),
#  ('m1514', 1),
#  ('m306', 1),
#  ('m1239', 1),
#  ('m1266', 1),
#  ('m333', 1),
#  ('m77', 1),
#  ('m239', 1),
#  ('m416', 1),
#  ('m1219', 1),
#  ('m568', 1),
#  ('m1128', 1),
#  ('m771', 1),
#  ('m100', 1),
#  ('m1198', 1),
#  ('m842', 1),
#  ('m843', 1),
#  ('m690', 1),
#  ('m853', 1),
#  ('m1055', 1),
#  ('m915', 1),
#  ('m1300', 1),
#  ('m1481', 1),
#  ('m835', 1),
#  ('m320', 1),
#  ('m521', 1),
#  ('m370', 1),
#  ('m631', 1),
#  ('m72', 1),
#  ('m702', 1),
#  ('m952', 1),
#  ('m834', 1),
#  ('m1297', 1),
#  ('m1298', 1),
#  ('m1112', 1),
#  ('m637', 1),
#  ('m1202', 1),
#  ('m781', 1),
#  ('m1268', 1),
#  ('m464', 1),
#  ('m1013', 1),
#  ('m1152', 1),
#  ('m1210', 1),
#  ('m60', 1),
#  ('m400', 1),
#  ('m1109', 1),
#  ('m823', 1),
#  ('m743', 1),
#  ('m960', 1),
#  ('m1009', 1),
#  ('m695', 1),
#  ('m643', 1),
#  ('m1043', 1),
#  ('m992', 1),
#  ('m389', 1),
#  ('m1218', 1),
#  ('m1222', 1),
#  ('m321', 1),
#  ('m603', 1),
#  ('m491', 1),
#  ('m512', 1),
#  ('m962', 1),
#  ('m1062', 1),
#  ('m492', 1),
#  ('m204', 1),
#  ('m243', 1),
#  ('m696', 1),
#  ('m520', 1),
#  ('m494', 1),
#  ('m502', 1),
#  ('m1123', 1),
#  ('m1122', 1),
#  ('m600', 1),
#  ('m1199', 1),
#  ('m343', 1),
#  ('m1066', 1),
#  ('m1099', 1),
#  ('m717', 1),
#  ('m1130', 1),
#  ('m1068', 1),
#  ('m1096', 1),
#  ('m644', 1),
#  ('m752', 1),
#  ('m1074', 1),
#  ('m1102', 1),
#  ('m148', 1),
#  ('m817', 1),
#  ('m1127', 1),
#  ('m1070', 1),
#  ('m1367', 1)]

# %%
top_recs = []
for t in counts:
    if t[1] > 1:
        top_recs.append(t[0])

# %%
top_recs
# Out:
# ['m3',
#  'm142',
#  'm208',
#  'm203',
#  'm237',
#  'm602',
#  'm99',
#  'm180',
#  'm173',
#  'm171',
#  'm6',
#  'm55',
#  'm11',
#  'm7',
#  'm654',
#  'm8',
#  'm233',
#  'm97',
#  'm422',
#  'm426',
#  'm22',
#  'm78',
#  'm126',
#  'm317',
#  'm152',
#  'm10',
#  'm63',
#  'm356',
#  'm190',
#  'm133',
#  'm175',
#  'm172',
#  'm209',
#  'm474',
#  'm181',
#  'm49',
#  'm184',
#  'm167',
#  'm80',
#  'm69',
#  'm432',
#  'm222',
#  'm123',
#  'm0',
#  'm287',
#  'm24',
#  'm131',
#  'm150',
#  'm513',
#  'm194',
#  'm199',
#  'm418',
#  'm257',
#  'm201',
#  'm745',
#  'm182',
#  'm424',
#  'm285',
#  'm185',
#  'm46',
#  'm155',
#  'm21',
#  'm292',
#  'm178',
#  'm653',
#  'm91',
#  'm92',
#  'm434',
#  'm734',
#  'm195',
#  'm153',
#  'm13',
#  'm174',
#  'm57',
#  'm427',
#  'm656',
#  'm191',
#  'm651',
#  'm301',
#  'm473',
#  'm143',
#  'm245',
#  'm193',
#  'm236',
#  'm479',
#  'm207',
#  'm95',
#  'm384',
#  'm478',
#  'm215',
#  'm482',
#  'm68',
#  'm170',
#  'm366',
#  'm81',
#  'm214',
#  'm159',
#  'm186',
#  'm149',
#  'm380',
#  'm587',
#  'm505',
#  'm98',
#  'm202',
#  'm791',
#  'm1006',
#  'm481',
#  'm247',
#  'm134',
#  'm210',
#  'm508',
#  'm27',
#  'm446',
#  'm312',
#  'm683',
#  'm196',
#  'm468',
#  'm522',
#  'm450',
#  'm256',
#  'm87',
#  'm200',
#  'm240',
#  'm218',
#  'm918',
#  'm267',
#  'm163',
#  'm297',
#  'm442',
#  'm254',
#  'm407',
#  'm227',
#  'm567',
#  'm217',
#  'm506',
#  'm500',
#  'm483',
#  'm708',
#  'm557',
#  'm249',
#  'm96',
#  'm714',
#  'm530',
#  'm741',
#  'm183',
#  'm54',
#  'm283',
#  'm691',
#  'm460',
#  'm128',
#  'm420',
#  'm392',
#  'm90',
#  'm318',
#  'm650',
#  'm1011',
#  'm410',
#  'm41',
#  'm524',
#  'm649',
#  'm169',
#  'm419',
#  'm461',
#  'm731',
#  'm229',
#  'm212',
#  'm23',
#  'm627',
#  'm264',
#  'm110',
#  'm497',
#  'm495',
#  'm316',
#  'm177',
#  'm70',
#  'm698',
#  'm462',
#  'm88',
#  'm130',
#  'm662',
#  'm179',
#  'm192',
#  'm94',
#  'm517',
#  'm402',
#  'm293',
#  'm404',
#  'm558',
#  'm136',
#  'm234',
#  'm1097',
#  'm64',
#  'm67',
#  'm812',
#  'm197',
#  'm704',
#  'm507',
#  'm32',
#  'm429',
#  'm409',
#  'm401',
#  'm844',
#  'm435',
#  'm12',
#  'm146',
#  'm43',
#  'm286',
#  'm268',
#  'm151',
#  'm121',
#  'm490',
#  'm615',
#  'm516',
#  'm115',
#  'm581',
#  'm82',
#  'm275',
#  'm1217',
#  'm122',
#  'm652',
#  'm804',
#  'm221',
#  'm525',
#  'm116',
#  'm272',
#  'm519',
#  'm226',
#  'm198',
#  'm549',
#  'm447',
#  'm565',
#  'm284',
#  'm633',
#  'm526',
#  'm628',
#  'm345',
#  'm274',
#  'm377',
#  'm958',
#  'm65',
#  'm769',
#  'm120',
#  'm300',
#  'm685',
#  'm658',
#  'm86',
#  'm707',
#  'm156',
#  'm30',
#  'm548',
#  'm632',
#  'm485',
#  'm31',
#  'm431',
#  'm503',
#  'm168',
#  'm486',
#  'm805',
#  'm583',
#  'm187',
#  'm85',
#  'm132',
#  'm25',
#  'm231',
#  'm657',
#  'm76',
#  'm789',
#  'm108',
#  'm332',
#  'm16',
#  'm403',
#  'm248',
#  'm740',
#  'm1038',
#  'm738',
#  'm127',
#  'm160',
#  'm250',
#  'm1285',
#  'm417',
#  'm692',
#  'm395',
#  'm289',
#  'm469',
#  'm339',
#  'm225',
#  'm472',
#  'm261',
#  'm501',
#  'm269',
#  'm955',
#  'm331',
#  'm511',
#  'm684',
#  'm271',
#  'm176',
#  'm454',
#  'm140',
#  'm302',
#  'm211',
#  'm639',
#  'm290',
#  'm162',
#  'm314',
#  'm504',
#  'm921',
#  'm52',
#  'm379',
#  'm330',
#  'm315',
#  'm1018',
#  'm577',
#  'm546',
#  'm528',
#  'm413',
#  'm488',
#  'm480',
#  'm606',
#  'm273',
#  'm14',
#  'm749',
#  'm1146',
#  'm470',
#  'm346',
#  'm216',
#  'm430',
#  'm706',
#  'm659',
#  'm728',
#  'm124',
#  'm509',
#  'm281',
#  'm299',
#  'm1010',
#  'm941',
#  'm355',
#  'm709',
#  'm613',
#  'm135',
#  'm965',
#  'm381',
#  'm47',
#  'm648',
#  'm610',
#  'm641',
#  'm660',
#  'm608',
#  'm944',
#  'm487',
#  'm428',
#  'm580',
#  'm493',
#  'm920',
#  'm964',
#  'm489',
#  'm44',
#  'm1117',
#  'm466',
#  'm1134',
#  'm645',
#  'm663',
#  'm536',
#  'm1044',
#  'm188',
#  'm736',
#  'm646',
#  'm968',
#  'm75',
#  'm477',
#  'm496',
#  'm51',
#  'm189',
#  'm498',
#  'm938',
#  'm527',
#  'm463',
#  'm386',
#  'm672',
#  'm590',
#  'm630',
#  'm959',
#  'm664',
#  'm779',
#  'm830',
#  'm874',
#  'm220',
#  'm846',
#  'm385',
#  'm762',
#  'm1141',
#  'm1108',
#  'm1047',
#  'm1020',
#  'm89',
#  'm614',
#  'm1072',
#  'm66',
#  'm1225',
#  'm235',
#  'm337',
#  'm1015',
#  'm575',
#  'm750',
#  'm270',
#  'm586',
#  'm304',
#  'm323',
#  'm1045',
#  'm618',
#  'm996',
#  'm319',
#  'm138',
#  'm344',
#  'm894',
#  'm566',
#  'm532',
#  'm296',
#  'm107',
#  'm223',
#  'm655',
#  'm607',
#  'm901',
#  'm895',
#  'm864',
#  'm967',
#  'm836',
#  'm50',
#  'm391',
#  'm276',
#  'm326',
#  'm514',
#  'm415',
#  'm689',
#  'm53',
#  'm624',
#  'm327',
#  'm814',
#  'm1',
#  'm475',
#  'm467',
#  'm723',
#  'm661',
#  'm251',
#  'm711',
#  'm125',
#  'm398',
#  'm48',
#  'm476',
#  'm353',
#  'm238',
#  'm106',
#  'm746',
#  'm1118',
#  'm914',
#  'm726',
#  'm923',
#  'm971',
#  'm1220',
#  'm1057',
#  'm1263',
#  'm678',
#  'm647',
#  'm465',
#  'm1196',
#  'm588',
#  'm1064',
#  'm510',
#  'm161',
#  'm71',
#  'm515',
#  'm601',
#  'm640',
#  'm847',
#  'm529',
#  'm604',
#  'm852',
#  'm617',
#  'm609',
#  'm810',
#  'm518',
#  'm433',
#  'm855',
#  'm1420',
#  'm213',
#  'm342',
#  'm205',
#  'm942',
#  'm206',
#  'm635',
#  'm1169',
#  'm1171',
#  'm457',
#  'm484',
#  'm9',
#  'm1069',
#  'm735',
#  'm113',
#  'm371',
#  'm1100',
#  'm970',
#  'm605',
#  'm1049',
#  'm788',
#  'm922',
#  'm948',
#  'm1008']

# %%
top10 = top_recs[:10]
top10
# Out:
# ['m3', 'm142', 'm208', 'm203', 'm237', 'm602', 'm99', 'm180', 'm173', 'm171']

# %%
top20 = top_recs[:20]
top20
# Out:
# ['m3',
#  'm142',
#  'm208',
#  'm203',
#  'm237',
#  'm602',
#  'm99',
#  'm180',
#  'm173',
#  'm171',
#  'm6',
#  'm55',
#  'm11',
#  'm7',
#  'm654',
#  'm8',
#  'm233',
#  'm97',
#  'm422',
#  'm426']

# %%
movie_names = pd.read_csv('/content/drive/MyDrive/Portfolio/Github-Recommender-System-master/movies.csv')

# %%
movie_names['movie_id'] = movie_names['movie_id'].apply(str)
movie_names['movie_id'] = 'm' + movie_names['movie_id'].astype(str)

# %%
movie_names.head()
# Out:
#    Unnamed: 0 movie_id              title  ... War  Western    year
# 0           0       m0   Toy Story (1995)  ...   0        0  1995.0
# 1           1       m1   GoldenEye (1995)  ...   0        0  1995.0
# 2           2       m2  Four Rooms (1995)  ...   0        0  1995.0
# 3           3       m3  Get Shorty (1995)  ...   0        0  1995.0
# 4           4       m4     Copycat (1995)  ...   0        0  1995.0
#
# [5 rows x 26 columns]

# %%
movie_names.loc[(movie_names['movie_id'].isin(top20))]
# Out:
#      Unnamed: 0 movie_id  ... Western    year
# 3             3       m3  ...       0  1995.0
# 6             6       m6  ...       0  1995.0
# 7             7       m7  ...       0  1995.0
# 8             8       m8  ...       0  1995.0
# 11           11      m11  ...       0  1995.0
# 55           55      m55  ...       0  1994.0
# 97           97      m97  ...       0  1991.0
# 99           99      m99  ...       0  1997.0
# 142         142     m142  ...       0  1965.0
# 171         171     m171  ...       0  1980.0
# 173         173     m173  ...       0  1981.0
# 180         180     m180  ...       0  1997.0
# 203         203     m203  ...       0  1985.0
# 208         208     m208  ...       0  1984.0
# 233         233     m233  ...       0  1975.0
# 237         237     m237  ...       0  1987.0
# 422         422     m422  ...       0  1982.0
# 426         426     m426  ...       0  1962.0
# 602         602     m602  ...       0  1954.0
# 654         654     m654  ...       0  1986.0
#
# [20 rows x 26 columns]

# %%
movie_names.loc[(movie_names['movie_id'].isin(top20)) & ((movie_names['Comedy'] == 1)|(movie_names['Drama'] == 1)|(movie_names['Romance'] == 1))]
# Out:
#      Unnamed: 0 movie_id  ... Western    year
# 3             3       m3  ...       0  1995.0
# 6             6       m6  ...       0  1995.0
# 7             7       m7  ...       0  1995.0
# 8             8       m8  ...       0  1995.0
# 55           55      m55  ...       0  1994.0
# 97           97      m97  ...       0  1991.0
# 99           99      m99  ...       0  1997.0
# 171         171     m171  ...       0  1980.0
# 180         180     m180  ...       0  1997.0
# 203         203     m203  ...       0  1985.0
# 208         208     m208  ...       0  1984.0
# 237         237     m237  ...       0  1987.0
# 422         422     m422  ...       0  1982.0
# 426         426     m426  ...       0  1962.0
# 654         654     m654  ...       0  1986.0
#
# [15 rows x 26 columns]

# %%
user_pref = movie_names.loc[movie_names['movie_id'].isin(u195list)]
user_pref
# Out:
#       Unnamed: 0 movie_id  ... Western    year
# 7              7       m7  ...       0  1995.0
# 24            24      m24  ...       0  1996.0
# 66            66      m66  ...       0  1994.0
# 107          107     m107  ...       0  1996.0
# 110          110     m110  ...       0  1996.0
# 152          152     m152  ...       0  1988.0
# 237          237     m237  ...       0  1987.0
# 284          284     m284  ...       0  1996.0
# 285          285     m285  ...       0  1996.0
# 305          305     m305  ...       0  1997.0
# 380          380     m380  ...       0  1994.0
# 381          381     m381  ...       0  1994.0
# 392          392     m392  ...       0  1993.0
# 410          410     m410  ...       0  1996.0
# 427          427     m427  ...       0  1971.0
# 654          654     m654  ...       0  1986.0
# 662          662     m662  ...       0  1979.0
# 691          691     m691  ...       0  1995.0
# 844          844     m844  ...       0  1996.0
# 1006        1006    m1006  ...       0  1997.0
# 1021        1021    m1021  ...       0  1997.0
# 1117        1117    m1117  ...       0  1978.0
#
# [22 rows x 26 columns]

# %%
user_prefs = user_pref[['genre_unknown', 'Action', 'Adventure', 'Animation',
       'Children', 'Comedy', 'Crime', 'Documentary', 'Drama', 'Fantasy',
       'Film-Noir', 'Horror', 'Musical', 'Mystery', 'Romance', 'Sci-Fi',
       'Thriller', 'War', 'Western']]
user_prefs.sum()
# Out:
# genre_unknown     0
# Action            0
# Adventure         1
# Animation         0
# Children          1
# Comedy           18
# Crime             0
# Documentary       1
# Drama             7
# Fantasy           1
# Film-Noir         0
# Horror            0
# Musical           0
# Mystery           0
# Romance           6
# Sci-Fi            1
# Thriller          0
# War               1
# Western           0
# dtype: int64
